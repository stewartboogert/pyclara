# %%
import pyclara
import sdds

# %% [markdown]
# ## Elegant input beam
# Unit of position are m, angular variables in rad, $t$ probably seconds, $p$ in $\gamma\beta$

# %%
input = sdds.load("../Run/FEBE_input.sdds")
pyclara.Plotting.Elegant.AllPS(input)

# %% [markdown]
# ## Elegant watch output (FEC-1 FOCUS)

# %%
watch = sdds.load("../Run/CLA-FEC1-SIM-FOCUS-01.SDDS")
pyclara.Plotting.Elegant.AllPS(watch)

# %%
import pyclara
import ocelot
from ocelot.gui.accelerator import *

# %%
oc = xsuite_twiss = pyclara.Converters.elegant2ocelot("../PostInjector/FEBE.lte",
                                                      line_name="FEBE",
                                                      start_element="CLA-FEA-SIM-DIP-04-END",
                                                      end_element="CLA-FED-SIM-DUMP-01-START",
                                                      elegant_twi="../Run/FEBE.twi")

# %%
t = ocelot.twiss(oc['ocelot_lattice'],oc['ocelot_twiss0'])
plot_opt_func(oc['ocelot_lattice'],t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 t = ocelot.twiss(oc['ocelot_lattice'],oc['ocelot_twiss0'])
# ----> 2 plot_opt_func(oc['ocelot_lattice'],t)
#
# NameError: name 'plot_opt_func' is not defined
